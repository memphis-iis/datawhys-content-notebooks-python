# %% [markdown]
# # Introduction to Jupyter Notebooks: Problem Solving
#
# In this notebook, we practice some common data analysis tasks.
#
# ## Import the Pandas Library
#
# First, we import the Pandas library.

# %%
import pandas as pd

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="h].Dva)5E?uZ/?o)}Hmq">pd</variable></variables><block type="importAs_Python" id="K/[k,J{sY+XHo(||R~Wx" x="16" y="-15"><field name="libraryName">pandas</field><field name="libraryAlias" id="h].Dva)5E?uZ/?o)}Hmq">pd</field></block></xml>

# %% [markdown]
# ## Read the Spreadsheet into a DataFrame
#
# Next, we read the spreadsheet into a DataFrame named `df`.

# %%
df = pd.read_csv('datasets/scores.csv')

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="4.h8Kg]KU0Q%!7O7KxIH">df</variable><variable id="h].Dva)5E?uZ/?o)}Hmq">pd</variable></variables><block type="variables_set" id="Z,2aeR$3aRO#,4ty|rGd" x="16" y="54"><field name="VAR" id="4.h8Kg]KU0Q%!7O7KxIH">df</field><value name="VALUE"><block type="varDoMethod_Python" id="ok3o?_ynlTBRRsWx3lzu"><field name="VAR" id="h].Dva)5E?uZ/?o)}Hmq">pd</field><field name="MEMBER">read_csv</field><data>pd:read_csv</data><value name="INPUT"><block type="text" id=",0`E.#Q4+dXsUX1$@-gJ"><field name="TEXT">scores.csv</field></block></value></block></value></block></xml>

# %% [markdown]
# ## Display the Contents of the DataFrame
#
# Next, we display a summary of the contents of the DataFrame.

# %%
df

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="4.h8Kg]KU0Q%!7O7KxIH">df</variable></variables><block type="variables_get" id="]S+gu;$*NZ/u)RV6XJeY" x="8" y="300"><field name="VAR" id="4.h8Kg]KU0Q%!7O7KxIH">df</field></block></xml>
# Out:
#       Name  Exam1  Exam2
# 0      Bob     45     56
# 1    Alice     89     87
# 2     Jane     62     98
# 3     Rick     99    100
# 4    Perry    100    100
# 5    Louis     76     79
# 6     Mike     88     85
# 7    Romeo     88     80
# 8   Juliet     84     96
# 9    Wendy     96     93
# 10   Peter     98     88
# 11   Homer     91    100
# 12    Bart     55     34
# 13    Lisa     87     86
# 14   Marge     79     97

# %% [markdown]
# ## Display an Individual Column in the DataFrame
#
# Next, we display the Exam1 column of the DataFrame.

# %%
df[['Exam1']]

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="4.h8Kg]KU0Q%!7O7KxIH">df</variable></variables><block type="indexer_Python" id="KGTT(LzPRCq[q^NWOdb=" x="62" y="157"><field name="VAR" id="4.h8Kg]KU0Q%!7O7KxIH">df</field><value name="INDEX"><block type="lists_create_with" id="WM~ihxn8THyhw?ytnZ)x"><mutation items="1"></mutation><value name="ADD0"><block type="text" id="-Kvnk*#7GLR8|qk-80Vx"><field name="TEXT">Exam1</field></block></value></block></value></block></xml>
# Out:
#     Exam1
# 0      45
# 1      89
# 2      62
# 3      99
# 4     100
# 5      76
# 6      88
# 7      88
# 8      84
# 9      96
# 10     98
# 11     91
# 12     55
# 13     87
# 14     79

# %% [markdown]
# ## Calculate the Average (Mean) Value of a Column in the DataFrame
#
# Next, we calculate the average value in the Exam1 column.

# %%
exam1 = df[['Exam1']]

exam1.mean()

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="pQ[bSUrE8E$B8s-e!@$k">exam1</variable><variable id="4.h8Kg]KU0Q%!7O7KxIH">df</variable></variables><block type="variables_set" id="Cz5zvadJAS9o~$=Ou:C?" x="45" y="110"><field name="VAR" id="pQ[bSUrE8E$B8s-e!@$k">exam1</field><value name="VALUE"><block type="indexer_Python" id="tGpT9%Dkx$`6R5yPsQR0"><field name="VAR" id="4.h8Kg]KU0Q%!7O7KxIH">df</field><value name="INDEX"><block type="lists_create_with" id="+3e{`vDM(bB_aaM]bO|i"><mutation items="1"></mutation><value name="ADD0"><block type="text" id="J}h)g{SYTXzzC^=;_(%M"><field name="TEXT">Exam1</field></block></value></block></value></block></value></block><block type="varDoMethod_Python" id=";5!Y,gd,*f8`h^=.!`A;" x="56" y="188"><field name="VAR" id="pQ[bSUrE8E$B8s-e!@$k">exam1</field><field name="MEMBER">mean</field><data>exam1:mean</data></block></xml>
# Out:
# Exam1    82.466667
# dtype: float64

# %% [markdown]
# ## Calculate the Average (Mean) Values of All Columns in the DataFrame
#
# Next, we calculate the average value of each and every column in the DataFrame.

# %%
df.mean()

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="4.h8Kg]KU0Q%!7O7KxIH">df</variable></variables><block type="varDoMethod_Python" id="k/3dq:vReuvZBOkM.+K=" x="8" y="188"><field name="VAR" id="4.h8Kg]KU0Q%!7O7KxIH">df</field><field name="MEMBER">mean</field><data>df:mean</data></block></xml>
# Out:
# Exam1    82.466667
# Exam2    85.266667
# dtype: float64

# %% [markdown]
# ## Display a Summary of Descriptive Statistics for Each Column in the DataFrame
#
# Lastly, we calculate a variety of descriptive statistcs for each column of `df`.

# %%
df.describe()

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="4.h8Kg]KU0Q%!7O7KxIH">df</variable></variables><block type="varDoMethod_Python" id="6KEn8pJz5gHtG5gq1._Q" x="8" y="188"><field name="VAR" id="4.h8Kg]KU0Q%!7O7KxIH">df</field><field name="MEMBER">describe</field><data>df:describe</data></block></xml>
# Out:
#             Exam1       Exam2
# count   15.000000   15.000000
# mean    82.466667   85.266667
# std     16.552370   18.300924
# min     45.000000   34.000000
# 25%     77.500000   82.500000
# 50%     88.000000   88.000000
# 75%     93.500000   97.500000
# max    100.000000  100.000000
